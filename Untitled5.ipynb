# %%
from IPython.display import Image
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
# %matplotlib inline  
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# # Bag of Features / Words
#
# ## Features are in essense textures; repetitions of basic elements within an object

# %%
images = Image(filename='/Users/Dylan/Desktop/Screen Shot 2016-05-18 at 5.55.24 PM.png', width=600)
images

# %% [markdown]
# ## By counting the number of times visual features occur in an image, we create a unique "bag of features"
#
# * A "bag" is a histogram counting the visual repetitive features
#
#
# * How do we find these "words?"
# * How do we count them?
# * How do we make sure that two images that are slightly different give the same results?

# %%
Image(filename='/Users/Dylan/Desktop/Screen Shot 2016-05-18 at 5.55.18 PM.png', width=600)

# %% [markdown]
# # Finding "Words"
#
# ## SIFT Descriptors
#
# ## First we need to create a list of sift descriptors. SIFT descriptors are extracted edge features found at unique points in an image.
#
# ## Edges provide us with much information :
#
# * Magnitude (how bold/strong the edge is measured by the derivitive with respect to x and y)
# * Orientation (tangent to the edge)
# * Position (where in a 2 dimensional plane the edge occurs)

# %%
a = np.matrix('0 0 0 255 255 255; 0 0 0 255 255 255 ;0 0 0 255 255 255; 0 0 0 255 255 255; 0 0 0 255 255 255 ;0 0 0 255 255 255')
print (a)
plt.imshow(a, interpolation='nearest', cmap='Greys')
plt.show()

gradientx = np.gradient(a)[1]
gradienty = np.gradient(a)[0]
plt.imshow(gradientx, interpolation='nearest', cmap='Greys')
print ("magnitude = " + str(np.linalg.norm(np.gradient(a))))
print (np.arctan2(gradientx, gradienty) * 180 / np.pi)
# Out:
# [[  0   0   0 255 255 255]
#  [  0   0   0 255 255 255]
#  [  0   0   0 255 255 255]
#  [  0   0   0 255 255 255]
#  [  0   0   0 255 255 255]
#  [  0   0   0 255 255 255]]
# magnitude = 441.67295593
# [[  0.   0.  90.  90.   0.   0.]
#  [  0.   0.  90.  90.   0.   0.]
#  [  0.   0.  90.  90.   0.   0.]
#  [  0.   0.  90.  90.   0.   0.]
#  [  0.   0.  90.  90.   0.   0.]
#  [  0.   0.  90.  90.   0.   0.]]

# %%
sift1 = Image(filename='/Users/Dylan/Desktop/Screen Shot 2016-05-18 at 6.46.44 PM.png', width=600)
sift2 = Image(filename='/Users/Dylan/Desktop/Screen Shot 2016-05-18 at 6.46.55 PM.png', width=600)
display(sift1, sift2)
